# %% [markdown]
# <a href="https://colab.research.google.com/github/lianlianliann/Retail-Demand-Forecasting-Sales-Analysis/blob/main/Retail_Demand_Forecasting_%26_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Retail Demand Forecasting & Sales Analysis
#
# Scope for this project: EDA + classical time series forecasting (ARIMA).
